# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import KFold
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from sklearn.model_selection import StratifiedShuffleSplit
import time
from tqdm import tqdm
import json
import scg
import importlib
import lfrog
from contextlib import redirect_stdout
from autorank import autorank, plot_stats
import scikit_posthocs as sp
import io
import warnings
warnings.filterwarnings('ignore')
from sklearn.model_selection import ShuffleSplit

# %%
seed = 40
torch.manual_seed(seed)
np.random.seed(seed)

# %% [markdown]
# ### Loading and downsampling data

# %%
data = pd.read_csv('../data/sine_data.csv')

y = data['y']
X = data.drop(columns='y')

sss = ShuffleSplit(n_splits=1, train_size=10000, random_state=42)
for train_idx, _ in sss.split(X, y):
    X_s = X.iloc[train_idx]
    y_s = y.iloc[train_idx]

# %% [markdown]
# ### K-fold setup

# %%
def generate_folds(X, y, n_folds = 10):
    kf = KFold(n_splits=n_folds, shuffle=True, random_state=42)
    folds = []
    splits = kf.split(X, y)
    for train_index, val_index in splits:
        X_train, X_val = X.iloc[train_index], X.iloc[val_index]
        y_train, y_val = y.iloc[train_index], y.iloc[val_index]
        folds.append({'Xt': X_train, 'Xv': X_val, 'yt': y_train, 'yv': y_val})
    return folds

# %%
folds = generate_folds(X_s, y_s, 10)

# %% [markdown]
# ### Auxiliary functions

# %%
def extend_with_last(arr, target_length):
    return arr + [arr[-1]] * (target_length - len(arr)) 

class FeedforwardNet(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim):
        super().__init__()
        self.hidden = nn.Linear(input_dim, hidden_dim)
        self.act = nn.ReLU()  
        self.output = nn.Linear(hidden_dim, output_dim)

    def forward(self, x):
        x = self.act(self.hidden(x))
        x = self.output(x)
        return x

def plot_results(results_in, show=True, title='Loss Curve for Classification Problem', fold_i='', ytop=0.8): 
    plt.plot(results_in['train_losses_by_epochs'], label=f'Train Loss: {fold_i}')
    plt.plot(results_in['val_losses'], label=f'Validation Loss: {fold_i}')
    plt.ylim(0, ytop) 
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title(title)
    if show == True:
        plt.legend()
        plt.show()

class CustomJSONEncoder(json.JSONEncoder):
    def default(self, obj):
        try:
            return super().default(obj)
        except TypeError:
            pass
        if hasattr(obj, '__dict__'):
            return obj.__dict__
        elif hasattr(obj, '__str__'):
            return str(obj)
        else:
            return f"<non-serializable: {type(obj).__name__}>"

def save_json(data, path, indent=4):
    with open(path, "w") as f:
        json.dump(data, f, indent=indent, cls=CustomJSONEncoder)

def extract_losses_and_accuracy(results):
    out = {}
    for dim_key in list(results.keys()):
        out_folds = {}
        for fold_key in list(results[dim_key].keys()):
            data = results[dim_key][fold_key]
            temp = {}
            temp['train_losses_by_epochs'] = data['train_losses_by_epochs']
            temp['val_losses'] = data['val_losses']
            temp['train_r2s'] = data['train_r2s']
            temp['val_r2s'] = data['val_r2s']
            temp['global_duration'] = data['global_duration']
            temp['epoch_durations'] = data['epoch_durations']
            temp['total_epochs'] = data['total_epochs']
            out_folds[fold_key] = temp
        out[dim_key] = out_folds
    return out

def plot_per_dim(dim_results, title="Loss Curve for Classification Problem 1: Hidden dimension = 1"):
    for key in list(dim_results.keys()):
        plot_results(dim_results[key], show=False, fold_i=key, title=title)
    plt.legend(loc='center left', bbox_to_anchor=(1, 0.3))
    plt.tight_layout()    
    plt.show()

def find_time_to_convergence(results_folded, threshold=0.005, max_time=1e6):
    out = {}
    val_wall = []
    val_epoch = []
    train_wall = []
    train_epoch = []
    for key in list(results_folded.keys()):
        val_wall.append(convergence_time(results_folded[key], threshold=threshold, max_time=max_time, key='val_losses', wall_time=True))
        val_epoch.append(convergence_time(results_folded[key], threshold=threshold, max_time=max_time, key='val_losses', wall_time=False))
        train_wall.append(convergence_time(results_folded[key], threshold=threshold, max_time=max_time, key='train_losses_by_epochs', wall_time=True))
        train_epoch.append(convergence_time(results_folded[key], threshold=threshold, max_time=max_time, key='train_losses_by_epochs', wall_time=False))
    out['val_wall'] = val_wall
    out['val_epoch'] = val_epoch
    out['train_wall'] = train_wall
    out['train_epoch'] = train_epoch
    return out

def convergence_time(result_run, threshold=0.005, max_time=1e6, key='val_losses', wall_time=True):
    list_in = np.array(result_run[key])
    n = len(list_in)
    for i in range(n):
        if all(v < threshold for v in list_in[i:]):
            if wall_time == True:
                out = np.array(result_run['epoch_durations'])
                return float(np.sum(out[:i + 1]))
            else: 
                return float(i + 1)
    return max_time

def estimate_avg_time_to_convergence(results_folded, threshold=0.005, max_time=1e6):
    res = find_time_to_convergence(results_folded, threshold, max_time)
    out = {}

    out['val_wall_avg'] = float(np.mean(res['val_wall']))
    out['val_wall_std'] = float(np.std(res['val_wall']))

    out['val_epoch_avg'] = float(np.mean(res['val_epoch']))
    out['val_epoch_std'] = float(np.std(res['val_epoch']))

    out['train_wall_avg'] = float(np.mean(res['train_wall']))
    out['train_wall_std'] = float(np.std(res['train_wall']))

    out['train_epoch_avg'] = float(np.mean(res['train_epoch']))
    out['train_epoch_std'] = float(np.std(res['train_epoch']))
    return out

def find_best_config(results, test_key='val_wall', threshold=0.05):
    best_key = None
    best_result = np.inf
    for key in list(results.keys()):
        temp = estimate_avg_time_to_convergence(results[key], threshold=threshold)[f"{test_key}_avg"]
        if temp < best_result:
            best_result = temp
            best_key = key
    return {'config': best_key, 'metric': best_result}

def sort_configs(results, test_key='val_wall', threshold=0.05):
    sorted_keys = sorted(
        results.keys(),
        key=lambda k: estimate_avg_time_to_convergence(results[k], threshold=threshold)[f"{test_key}_avg"],
        reverse=False
    )
    return sorted_keys

# %% [markdown]
# ## SGD

# %% [markdown]
# ### Model Training function

# %%
def train_sgd_model(fold, hidden_dim=2, input_dim=1, output_dim=1, 
                         batch_size=1, learning_rate=0.01, max_epochs=10, 
                         to_print=True, patience=10): 
    X_val = torch.tensor(fold['Xv'].values, dtype=torch.float32)
    y_val = torch.tensor(fold['yv'].values, dtype=torch.float32)
    X_train = torch.tensor(fold['Xt'].values, dtype=torch.float32)
    y_train = torch.tensor(fold['yt'].values, dtype=torch.float32)

    train_dataset = TensorDataset(X_train, y_train)
    loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

    model = FeedforwardNet(input_dim=input_dim, hidden_dim=hidden_dim, output_dim=output_dim)
    criterion = nn.MSELoss()
    optimizer = optim.SGD(model.parameters(), lr=learning_rate)

    train_losses, val_losses = [], []
    train_r2s, val_r2s = [], []
    times = []
    best_val_loss = float('inf')
    epochs_since_improve = 0
    global_start = time.time()
    total_epochs_ran = 0

    def r2_score(y_true, y_pred):
        ss_res = torch.sum((y_true - y_pred) ** 2)
        ss_tot = torch.sum((y_true - torch.mean(y_true)) ** 2)
        return 1 - ss_res / ss_tot

    for epoch in range(max_epochs):
        local_start = time.time()
        model.train()
        train_loss = 0.0
        preds_all = []
        y_all = []
        for batch_X, batch_y in loader: 
            optimizer.zero_grad()
            outputs = model(batch_X)
            outputs = outputs.view(-1)       
            batch_y = batch_y.view(-1)       
            loss = criterion(outputs, batch_y)
            loss.backward()
            optimizer.step()
            train_loss += loss.item() * batch_y.size(0)
            preds_all.append(outputs.detach())
            y_all.append(batch_y)
        
        preds_all = torch.cat(preds_all)
        y_all = torch.cat(y_all)
        avg_train_loss = train_loss / len(y_train)
        train_r2 = r2_score(y_all, preds_all).item()
        train_losses.append(avg_train_loss)
        train_r2s.append(train_r2)
        
        model.eval()
        with torch.no_grad():
            val_outputs = model(X_val).view(-1)
            val_loss = criterion(val_outputs, y_val.view(-1)).item()
            val_r2 = r2_score(y_val.view(-1), val_outputs).item()
            val_losses.append(val_loss)
            val_r2s.append(val_r2)

        if val_loss < best_val_loss - 1e-6:  
            best_val_loss = val_loss
            epochs_since_improve = 0
        else:
            epochs_since_improve += 1

        local_stop = time.time()
        local_duration = local_stop - local_start
        times.append(local_duration)
        total_epochs_ran += 1

        if to_print:
            print(f"Epoch {epoch+1}/{max_epochs} | "
                  f"Train Loss: {avg_train_loss:.4f} | "
                  f"Train R²: {train_r2:.4f} | "
                  f"Val Loss: {val_loss:.4f} | "
                  f"Val R²: {val_r2:.4f} | "
                  f"Duration: {local_duration:.4f}")
            
        if epochs_since_improve >= patience:
            if to_print:
                print(f"Early stopping at epoch {epoch+1}")
            break
            
    global_end = time.time()
    global_duration = global_end - global_start

    results = {
        "model": model,
        "train_losses_by_epochs": train_losses,
        "val_losses": val_losses,
        "train_r2s": train_r2s,
        "val_r2s": val_r2s,
        "global_duration": global_duration, 
        "epoch_durations": times,
        "total_epochs": total_epochs_ran
    }
    return results

# %% [markdown]
# ### Evals of dimension and learning rate

# %%
res = train_sgd_model(folds[0], hidden_dim=5, max_epochs=10)
plot_results(res)
# Out:
# Epoch 1/10 | Train Loss: 0.2313 | Train R²: 0.7707 | Val Loss: 0.2495 | Val R²: 0.7505 | Duration: 8.4353
# Epoch 2/10 | Train Loss: 0.1484 | Train R²: 0.8529 | Val Loss: 0.0954 | Val R²: 0.9046 | Duration: 7.9426
# Epoch 3/10 | Train Loss: 0.0923 | Train R²: 0.9085 | Val Loss: 0.0605 | Val R²: 0.9395 | Duration: 7.8902
# Epoch 4/10 | Train Loss: 0.0654 | Train R²: 0.9352 | Val Loss: 0.0801 | Val R²: 0.9199 | Duration: 8.0277
# Epoch 5/10 | Train Loss: 0.0490 | Train R²: 0.9515 | Val Loss: 0.0480 | Val R²: 0.9521 | Duration: 7.7883
# Epoch 6/10 | Train Loss: 0.0405 | Train R²: 0.9599 | Val Loss: 0.0256 | Val R²: 0.9744 | Duration: 7.8321
# Epoch 7/10 | Train Loss: 0.0366 | Train R²: 0.9637 | Val Loss: 0.0206 | Val R²: 0.9794 | Duration: 7.8490
# Epoch 8/10 | Train Loss: 0.0323 | Train R²: 0.9680 | Val Loss: 0.0163 | Val R²: 0.9837 | Duration: 8.6116
# Epoch 9/10 | Train Loss: 0.0308 | Train R²: 0.9694 | Val Loss: 0.0176 | Val R²: 0.9824 | Duration: 9.3954
# Epoch 10/10 | Train Loss: 0.0280 | Train R²: 0.9722 | Val Loss: 0.0213 | Val R²: 0.9787 | Duration: 10.3996

# %%
def find_optimal_hidden_layers(folds, dim_list = [1, 2, 3], max_epochs=20, learning_rate=0.01):
    results = {}
    for n in dim_list:
        results_per_size = {}
        for i in tqdm(range(len(folds))):
            results_per_size[f'fold_{i}'] = train_sgd_model(folds[i], hidden_dim=n, max_epochs=max_epochs, learning_rate=learning_rate, to_print=False)
        results[f'dim_{n}'] = results_per_size
    return results

# %%
dim_results = find_optimal_hidden_layers(folds, dim_list=[2, 3, 4, 5, 6, 7])
save_json(extract_losses_and_accuracy(dim_results), '../results/regression_1/hidden_dim_test.json')
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# 100%|██████████| 10/10 [13:31<00:00, 81.10s/it]
# 100%|██████████| 10/10 [14:12<00:00, 85.27s/it]
# 100%|██████████| 10/10 [15:08<00:00, 90.81s/it]
# 100%|██████████| 10/10 [15:25<00:00, 92.53s/it]
# 100%|██████████| 10/10 [2:00:06<00:00, 720.60s/it]
# 100%|██████████| 10/10 [33:40<00:00, 202.03s/it]

# %%
plot_per_dim(dim_results['dim_2'], title="Loss Curve for Classification Problem 1: Hidden dimension = 2")

# %%
plot_per_dim(dim_results['dim_3'], title="Loss Curve for Classification Problem 1: Hidden dimension = 3")

# %%
plot_per_dim(dim_results['dim_4'], title="Loss Curve for Classification Problem 1: Hidden dimension = 4")

# %%
plot_per_dim(dim_results['dim_5'], title="Loss Curve for Classification Problem 1: Hidden dimension = 5")

# %%
plot_per_dim(dim_results['dim_6'], title="Loss Curve for Classification Problem 1: Hidden dimension = 6")

# %%
plot_per_dim(dim_results['dim_7'], title="Loss Curve for Classification Problem 2: Hidden dimension = 7")

# %%
def find_optimal_learning_rate(folds, lr_list = [1, 2, 3], max_epochs=20):
    results = {}
    for l in lr_list:
        results_per_size = {}
        for i in tqdm(range(len(folds))):
            results_per_size[f'fold_{i}'] = train_sgd_model(folds[i], hidden_dim=5, max_epochs=max_epochs, learning_rate=l, to_print=False, patience=10)
        results[f'lr_{l}'] = results_per_size
    return results

# %%
lr_candidates = [1e-4, 3e-4, 1e-3, 3e-3, 1e-2, 3e-2, 1e-1]

dim_results_lr = find_optimal_learning_rate(folds, lr_list=lr_candidates)
save_json(extract_losses_and_accuracy(dim_results_lr), '../results/regression_1/lr_test.json')
# Out:
# 100%|██████████| 10/10 [15:43<00:00, 94.37s/it]
# 100%|██████████| 10/10 [1:24:56<00:00, 509.62s/it]
# 100%|██████████| 10/10 [18:18<00:00, 109.80s/it]
# 100%|██████████| 10/10 [19:00<00:00, 114.08s/it]
# 100%|██████████| 10/10 [20:05<00:00, 120.54s/it]
# 100%|██████████| 10/10 [58:12<00:00, 349.25s/it]
# 100%|██████████| 10/10 [16:38<00:00, 99.85s/it]

# %%
plot_per_dim(dim_results_lr['lr_0.0001'], title="Loss Curve for Classification Problem 1: Learning Rate = 0.0001")

# %%
plot_per_dim(dim_results_lr['lr_0.0003'], title="Loss Curve for Classification Problem 1: Learning Rate = 0.0003")

# %%
plot_per_dim(dim_results_lr['lr_0.001'], title="Loss Curve for Classification Problem 1: Learning Rate = 0.001")

# %%
plot_per_dim(dim_results_lr['lr_0.003'], title="Loss Curve for Classification Problem 1: Learning Rate = 0.003")

# %%
plot_per_dim(dim_results_lr['lr_0.01'], title="Loss Curve for Classification Problem 1: Learning Rate = 0.01")

# %%
plot_per_dim(dim_results_lr['lr_0.03'], title="Loss Curve for Classification Problem 1: Learning Rate = 0.03")

# %%
plot_per_dim(dim_results_lr['lr_0.1'], title="Loss Curve for Classification Problem 1: Learning Rate = 0.1")

# %% [markdown]
# ## SCG

# %%
importlib.reload(scg)
from scg import SCG

def train_scg_model(
    fold,
    hidden_dim=5,
    input_dim=1,
    output_dim=1,
    max_epochs=10,
    sigma=1e-4,
    lambd=1e-6,
    to_print=True,
    patience=10
):
    X_val = torch.tensor(fold['Xv'].values, dtype=torch.float32)
    y_val = torch.tensor(fold['yv'].values, dtype=torch.float32).view(-1)
    X_train = torch.tensor(fold['Xt'].values, dtype=torch.float32)
    y_train = torch.tensor(fold['yt'].values, dtype=torch.float32).view(-1)

    model = FeedforwardNet(input_dim=input_dim, hidden_dim=hidden_dim, output_dim=output_dim)
    criterion = nn.MSELoss() 
    optimizer = SCG(model.parameters(), sigma=sigma, lambd=lambd)

    train_losses = []
    val_losses = []
    train_r2s = []
    val_r2s = []
    times = []
    best_val_loss = float('inf')
    epochs_since_improve = 0
    global_start = time.time()
    total_epochs_ran = 0

    def r2_score(y_true, y_pred):
        ss_res = torch.sum((y_true - y_pred) ** 2)
        ss_tot = torch.sum((y_true - torch.mean(y_true)) ** 2)
        return 1 - ss_res / ss_tot

    for epoch in range(max_epochs):
        local_start = time.time()
        model.train()

        def closure():
            optimizer.zero_grad()
            outputs = model(X_train).view(-1)  
            loss = criterion(outputs, y_train)
            return loss

        loss = optimizer.step(closure)
        train_loss = loss.item()

        with torch.no_grad():
            outputs = model(X_train).view(-1)
            train_r2 = r2_score(y_train, outputs).item()

        model.eval()
        with torch.no_grad():
            val_outputs = model(X_val).view(-1)
            val_loss = criterion(val_outputs, y_val).item()
            val_r2 = r2_score(y_val, val_outputs).item()

        train_losses.append(train_loss)
        train_r2s.append(train_r2)
        val_losses.append(val_loss)
        val_r2s.append(val_r2)

        if val_loss < best_val_loss - 1e-6:
            best_val_loss = val_loss
            epochs_since_improve = 0
        else:
            epochs_since_improve += 1

        local_stop = time.time()
        local_duration = local_stop - local_start
        times.append(local_duration)
        total_epochs_ran += 1

        if to_print:
            print(f"Epoch {epoch+1}/{max_epochs} | "
                  f"Train Loss: {train_loss:.4f} | "
                  f"Train R²: {train_r2:.4f} | "
                  f"Val Loss: {val_loss:.4f} | "
                  f"Val R²: {val_r2:.4f} | "
                  f"Duration: {local_duration:.4f}")

        if epochs_since_improve >= patience:
            if to_print:
                print(f"Early stopping at epoch {epoch+1}")
            break

    global_end = time.time()
    global_duration = global_end - global_start

    results = {
        "model": model,
        "train_losses_by_epochs": train_losses,
        "val_losses": val_losses,
        "train_r2s": train_r2s,
        "val_r2s": val_r2s,
        "global_duration": global_duration,
        "epoch_durations": times,
        "total_epochs": total_epochs_ran
    }
    return results

# %%
def find_optimal_hidden_layer_scg(folds, dim_list = [1, 2, 3], max_epochs=2000):
    results = {}
    for n in dim_list:
        results_per_size = {}
        for i in tqdm(range(len(folds))):
            results_per_size[f'fold_{i}'] = train_scg_model(folds[i], hidden_dim=n, max_epochs=max_epochs, lambd=1e-1, sigma=1e-1, to_print=False, patience=1000)
        results[f'dim_{n}'] = results_per_size
    return results

# %%
dim_results_scg = find_optimal_hidden_layer_scg(folds, dim_list=[5], max_epochs=1000)
save_json(extract_losses_and_accuracy(dim_results_scg), '../results/regression_1/hidden_dim_test_scg.json')
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# 100%|██████████| 10/10 [00:42<00:00,  4.25s/it]

# %%
plot_per_dim(dim_results_scg['dim_5'])

# %%
res = train_scg_model(folds[0], hidden_dim=8, max_epochs=1000, patience=300)
plot_results(res)
# Out:
# Epoch 1/1000 | Train Loss: 0.7998 | Train R²: 0.2072 | Val Loss: 0.7947 | Val R²: 0.2053 | Duration: 0.0056
# Epoch 2/1000 | Train Loss: 0.2911 | Train R²: 0.7115 | Val Loss: 0.2887 | Val R²: 0.7113 | Duration: 0.0040
# Epoch 3/1000 | Train Loss: 0.2745 | Train R²: 0.7278 | Val Loss: 0.2758 | Val R²: 0.7242 | Duration: 0.0041
# Epoch 4/1000 | Train Loss: 0.2670 | Train R²: 0.7353 | Val Loss: 0.2717 | Val R²: 0.7283 | Duration: 0.0042
# Epoch 5/1000 | Train Loss: 0.2570 | Train R²: 0.7452 | Val Loss: 0.2615 | Val R²: 0.7385 | Duration: 0.0040
# Epoch 6/1000 | Train Loss: 0.2495 | Train R²: 0.7527 | Val Loss: 0.2517 | Val R²: 0.7483 | Duration: 0.0038
# Epoch 7/1000 | Train Loss: 0.2452 | Train R²: 0.7570 | Val Loss: 0.2476 | Val R²: 0.7524 | Duration: 0.0045
# Epoch 8/1000 | Train Loss: 0.2414 | Train R²: 0.7607 | Val Loss: 0.2435 | Val R²: 0.7565 | Duration: 0.0045
# Epoch 9/1000 | Train Loss: 0.2384 | Train R²: 0.7637 | Val Loss: 0.2409 | Val R²: 0.7591 | Duration: 0.0150
# Epoch 10/1000 | Train Loss: 0.2352 | Train R²: 0.7668 | Val Loss: 0.2375 | Val R²: 0.7625 | Duration: 0.0119
# Epoch 11/1000 | Train Loss: 0.2316 | Train R²: 0.7704 | Val Loss: 0.2341 | Val R²: 0.7659 | Duration: 0.0292
# Epoch 12/1000 | Train Loss: 0.2282 | Train R²: 0.7738 | Val Loss: 0.2303 | Val R²: 0.7697 | Duration: 0.0191
# Epoch 984/1000 | Train Loss: 0.0189 | Train R²: 0.9812 | Val Loss: 0.0181 | Val R²: 0.9819 | Duration: 0.0195
# Epoch 985/1000 | Train Loss: 0.0189 | Train R²: 0.9812 | Val Loss: 0.0181 | Val R²: 0.9819 | Duration: 0.0291
# Epoch 986/1000 | Train Loss: 0.0189 | Train R²: 0.9812 | Val Loss: 0.0181 | Val R²: 0.9819 | Duration: 0.0595
# Epoch 987/1000 | Train Loss: 0.0189 | Train R²: 0.9813 | Val Loss: 0.0181 | Val R²: 0.9819 | Duration: 0.0253
# Epoch 988/1000 | Train Loss: 0.0189 | Train R²: 0.9813 | Val Loss: 0.0181 | Val R²: 0.9819 | Duration: 0.0390
# Epoch 989/1000 | Train Loss: 0.0189 | Train R²: 0.9813 | Val Loss: 0.0181 | Val R²: 0.9819 | Duration: 0.0128
# Epoch 990/1000 | Train Loss: 0.0189 | Train R²: 0.9813 | Val Loss: 0.0181 | Val R²: 0.9819 | Duration: 0.0093
# Epoch 991/1000 | Train Loss: 0.0189 | Train R²: 0.9813 | Val Loss: 0.0181 | Val R²: 0.9819 | Duration: 0.0079
# Epoch 992/1000 | Train Loss: 0.0189 | Train R²: 0.9813 | Val Loss: 0.0181 | Val R²: 0.9819 | Duration: 0.0052
# Epoch 993/1000 | Train Loss: 0.0189 | Train R²: 0.9813 | Val Loss: 0.0181 | Val R²: 0.9819 | Duration: 0.0083
# Epoch 994/1000 | Train Loss: 0.0189 | Train R²: 0.9813 | Val Loss: 0.0181 | Val R²: 0.9819 | Duration: 0.0064
# Epoch 995/1000 | Train Loss: 0.0189 | Train R²: 0.9813 | Val Loss: 0.0181 | Val R²: 0.9819 | Duration: 0.0200
# Epoch 996/1000 | Train Loss: 0.0188 | Train R²: 0.9813 | Val Loss: 0.0181 | Val R²: 0.9819 | Duration: 0.0371
# Epoch 997/1000 | Train Loss: 0.0188 | Train R²: 0.9813 | Val Loss: 0.0181 | Val R²: 0.9819 | Duration: 0.0125
# Epoch 998/1000 | Train Loss: 0.0188 | Train R²: 0.9813 | Val Loss: 0.0180 | Val R²: 0.9820 | Duration: 0.0199
# Epoch 999/1000 | Train Loss: 0.0188 | Train R²: 0.9813 | Val Loss: 0.0180 | Val R²: 0.9820 | Duration: 0.0222
# Epoch 1000/1000 | Train Loss: 0.0188 | Train R²: 0.9813 | Val Loss: 0.0180 | Val R²: 0.9820 | Duration: 0.0142

# %%
def optimize_hyper_params_scg(folds, sig_list, lam_list, max_epochs=1000):
    results = {}
    for s in sig_list:
        for l in lam_list:
            results_per_config = {}
            for i in tqdm(range(len(folds))):
                results_per_config[f'fold_{i}'] = train_scg_model(folds[i], max_epochs=max_epochs, sigma=s, lambd=l, to_print=False, patience=1000)
            results[f'sigma_{s}_lambda_{l}'] = results_per_config
    return results

# %%
sigmas = [1e-6, 3e-6, 1e-5, 3e-5, 1e-4, 3e-4]
lambdas = [1e-6, 1e-5, 1e-4]

scg_param_results = optimize_hyper_params_scg(folds, sigmas, lambdas)
save_json(extract_losses_and_accuracy(scg_param_results), '../results/regression_1/scg_hyperparam_test.json')
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# 100%|██████████| 10/10 [00:51<00:00,  5.20s/it]
# 100%|██████████| 10/10 [00:46<00:00,  4.61s/it]
# 100%|██████████| 10/10 [00:59<00:00,  5.98s/it]
# 100%|██████████| 10/10 [01:13<00:00,  7.37s/it]
# 100%|██████████| 10/10 [01:06<00:00,  6.70s/it]
# 100%|██████████| 10/10 [01:06<00:00,  6.69s/it]
# 100%|██████████| 10/10 [01:08<00:00,  6.86s/it]
# 100%|██████████| 10/10 [01:11<00:00,  7.11s/it]
# 100%|██████████| 10/10 [01:07<00:00,  6.71s/it]
# 100%|██████████| 10/10 [01:01<00:00,  6.10s/it]
# 100%|██████████| 10/10 [01:05<00:00,  6.59s/it]
# 100%|██████████| 10/10 [01:02<00:00,  6.22s/it]
# 100%|██████████| 10/10 [01:09<00:00,  6.98s/it]
# 100%|██████████| 10/10 [00:58<00:00,  5.81s/it]
# 100%|██████████| 10/10 [01:08<00:00,  6.85s/it]
# 100%|██████████| 10/10 [01:01<00:00,  6.20s/it]
# 100%|██████████| 10/10 [01:06<00:00,  6.64s/it]
# 100%|██████████| 10/10 [01:06<00:00,  6.68s/it]

# %%
sort_configs(scg_param_results, threshold=0.05)
# Out:
# ['sigma_0.0001_lambda_0.0001',
#  'sigma_1e-05_lambda_1e-05',
#  'sigma_0.0003_lambda_0.0001',
#  'sigma_0.0001_lambda_1e-06',
#  'sigma_1e-06_lambda_1e-06',
#  'sigma_3e-06_lambda_1e-06',
#  'sigma_3e-05_lambda_1e-05',
#  'sigma_0.0003_lambda_1e-05',
#  'sigma_3e-06_lambda_1e-05',
#  'sigma_0.0003_lambda_1e-06',
#  'sigma_3e-06_lambda_0.0001',
#  'sigma_1e-05_lambda_0.0001',
#  'sigma_1e-05_lambda_1e-06',
#  'sigma_1e-06_lambda_1e-05',
#  'sigma_3e-05_lambda_0.0001',
#  'sigma_1e-06_lambda_0.0001',
#  'sigma_3e-05_lambda_1e-06',
#  'sigma_0.0001_lambda_1e-05']

# %%
estimate_avg_time_to_convergence(scg_param_results['sigma_0.0001_lambda_0.0001'], threshold=0.1)
# Out:
# {'val_wall_avg': 0.35477285385131835,
#  'val_wall_std': 0.1454466158440327,
#  'val_epoch_avg': 53.2,
#  'val_epoch_std': 22.457960726655482,
#  'train_wall_avg': 0.35270659923553466,
#  'train_wall_std': 0.14236678233829914,
#  'train_epoch_avg': 52.9,
#  'train_epoch_std': 21.920082116634507}

# %%
plot_per_dim(scg_param_results['sigma_0.0001_lambda_1e-05'])

# %% [markdown]
# ## LFrog

# %%
importlib.reload(lfrog)
from lfrog import LeapfrogOptimizer

def train_leapfrog_model(
    fold,
    hidden_dim=5,
    input_dim=1,
    output_dim=1,
    max_epochs=10,
    time_step=0.5,
    delta_max=1.0,
    tol_grad=1e-5,
    j_threshold=2,
    to_print=True,
    patience=10
):
    # Prepare data
    X_val = torch.tensor(fold['Xv'].values, dtype=torch.float32)
    y_val = torch.tensor(fold['yv'].values, dtype=torch.float32).view(-1)
    X_train = torch.tensor(fold['Xt'].values, dtype=torch.float32)
    y_train = torch.tensor(fold['yt'].values, dtype=torch.float32).view(-1)

    model = FeedforwardNet(input_dim=input_dim, hidden_dim=hidden_dim, output_dim=output_dim)
    criterion = nn.MSELoss()

    optimizer = LeapfrogOptimizer(
        model.parameters(),
        time_step=time_step,
        delta_max=delta_max,
        tol_grad=tol_grad,
        j_threshold=j_threshold
    )

    train_losses = []
    val_losses = []
    train_r2s = []
    val_r2s = []
    times = []
    best_val_loss = float('inf')
    epochs_since_improve = 0
    global_start = time.time()
    total_epochs_ran = 0

    def r2_score(y_true, y_pred):
        ss_res = torch.sum((y_true - y_pred) ** 2)
        ss_tot = torch.sum((y_true - torch.mean(y_true)) ** 2)
        return 1 - ss_res / ss_tot

    for epoch in range(max_epochs):
        local_start = time.time()
        model.train()

        # Closure for Leapfrog: must compute full-batch loss + backward
        def closure():
            optimizer.zero_grad()
            outputs = model(X_train).view(-1)
            loss = criterion(outputs, y_train)
            loss.backward()
            return loss

        # Step the optimizer
        loss = optimizer.step(closure)
        train_loss = loss.item()

        with torch.no_grad():
            outputs = model(X_train).view(-1)
            train_r2 = r2_score(y_train, outputs).item()

        model.eval()
        with torch.no_grad():
            val_outputs = model(X_val).view(-1)
            val_loss = criterion(val_outputs, y_val).item()
            val_r2 = r2_score(y_val, val_outputs).item()

        train_losses.append(train_loss)
        train_r2s.append(train_r2)
        val_losses.append(val_loss)
        val_r2s.append(val_r2)

        if val_loss < best_val_loss - 1e-6:
            best_val_loss = val_loss
            epochs_since_improve = 0
        else:
            epochs_since_improve += 1

        local_stop = time.time()
        local_duration = local_stop - local_start
        times.append(local_duration)
        total_epochs_ran += 1

        if to_print:
            grad_norm = optimizer.grad_norm()
            print(f"Epoch {epoch+1}/{max_epochs} | "
                  f"Train Loss: {train_loss:.4f} | "
                  f"Train R²: {train_r2:.4f} | "
                  f"Val Loss: {val_loss:.4f} | "
                  f"Val R²: {val_r2:.4f} | "
                  f"Grad Norm: {grad_norm:.4e} | "
                  f"Duration: {local_duration:.4f}")

        if epochs_since_improve >= patience:
            if to_print:
                print(f"Early stopping at epoch {epoch+1}")
            break

        if optimizer.grad_norm() <= tol_grad:
            if to_print:
                print(f"Converged at epoch {epoch+1}")
            break

    global_end = time.time()
    global_duration = global_end - global_start

    results = {
        "model": model,
        "train_losses_by_epochs": train_losses,
        "val_losses": val_losses,
        "train_r2s": train_r2s,
        "val_r2s": val_r2s,
        "global_duration": global_duration,
        "epoch_durations": times,
        "total_epochs": total_epochs_ran
    }
    return results

# %%
res = train_leapfrog_model(folds[0], hidden_dim=5, delta_max=0.5, time_step=0.1, max_epochs=1000, patience=300)
plot_results(res)
# Out:
# Epoch 1/1000 | Train Loss: 1.3700 | Train R²: -0.3581 | Val Loss: 1.3730 | Val R²: -0.3730 | Grad Norm: 2.5943e+00 | Duration: 0.0043
# Epoch 2/1000 | Train Loss: 1.3042 | Train R²: -0.2929 | Val Loss: 1.3053 | Val R²: -0.3052 | Grad Norm: 2.4823e+00 | Duration: 0.0035
# Epoch 3/1000 | Train Loss: 1.1837 | Train R²: -0.1734 | Val Loss: 1.1814 | Val R²: -0.1814 | Grad Norm: 2.2721e+00 | Duration: 0.0043
# Epoch 4/1000 | Train Loss: 1.0278 | Train R²: -0.0189 | Val Loss: 1.0219 | Val R²: -0.0218 | Grad Norm: 1.9886e+00 | Duration: 0.0050
# Epoch 5/1000 | Train Loss: 0.8599 | Train R²: 0.1476 | Val Loss: 0.8507 | Val R²: 0.1493 | Grad Norm: 1.6632e+00 | Duration: 0.0049
# Epoch 6/1000 | Train Loss: 0.7022 | Train R²: 0.3039 | Val Loss: 0.6915 | Val R²: 0.3085 | Grad Norm: 1.3331e+00 | Duration: 0.0034
# Epoch 7/1000 | Train Loss: 0.5708 | Train R²: 0.4342 | Val Loss: 0.5610 | Val R²: 0.4390 | Grad Norm: 1.0474e+00 | Duration: 0.0025
# Epoch 8/1000 | Train Loss: 0.4747 | Train R²: 0.5294 | Val Loss: 0.4687 | Val R²: 0.5313 | Grad Norm: 8.5742e-01 | Duration: 0.0031
# Epoch 9/1000 | Train Loss: 0.4205 | Train R²: 0.5832 | Val Loss: 0.4211 | Val R²: 0.5790 | Grad Norm: 8.3638e-01 | Duration: 0.0027
# Epoch 10/1000 | Train Loss: 0.4078 | Train R²: 0.5958 | Val Loss: 0.4176 | Val R²: 0.5824 | Grad Norm: 9.9132e-01 | Duration: 0.0028
# Epoch 11/1000 | Train Loss: 0.4092 | Train R²: 0.5943 | Val Loss: 0.4245 | Val R²: 0.5755 | Grad Norm: 1.0917e+00 | Duration: 0.0024
# Epoch 12/1000 | Train Loss: 0.3925 | Train R²: 0.6109 | Val Loss: 0.4078 | Val R²: 0.5922 | Grad Norm: 1.0320e+00 | Duration: 0.0045
# Epoch 13/1000 | Train Loss: 0.3679 | Train R²: 0.6353 | Val Loss: 0.3824 | Val R²: 0.6176 | Grad Norm: 9.2094e-01 | Duration: 0.0028
# Epoch 14/1000 | Train Loss: 0.3396 | Train R²: 0.6633 | Val Loss: 0.3528 | Val R²: 0.6472 | Grad Norm: 7.6305e-01 | Duration: 0.0023
# Epoch 15/1000 | Train Loss: 0.3126 | Train R²: 0.6901 | Val Loss: 0.3238 | Val R²: 0.6763 | Grad Norm: 5.6159e-01 | Duration: 0.0110
# Epoch 16/1000 | Train Loss: 0.2906 | Train R²: 0.7119 | Val Loss: 0.2994 | Val R²: 0.7006 | Grad Norm: 3.4540e-01 | Duration: 0.0070
# Epoch 17/1000 | Train Loss: 0.2800 | Train R²: 0.7224 | Val Loss: 0.2864 | Val R²: 0.7136 | Grad Norm: 1.9332e-01 | Duration: 0.0049
# Epoch 18/1000 | Train Loss: 0.2790 | Train R²: 0.7234 | Val Loss: 0.2838 | Val R²: 0.7163 | Grad Norm: 2.4213e-01 | Duration: 0.0058
# Epoch 19/1000 | Train Loss: 0.2784 | Train R²: 0.7240 | Val Loss: 0.2826 | Val R²: 0.7174 | Grad Norm: 2.8571e-01 | Duration: 0.0041
# Epoch 20/1000 | Train Loss: 0.2768 | Train R²: 0.7256 | Val Loss: 0.2809 | Val R²: 0.7191 | Grad Norm: 2.9313e-01 | Duration: 0.0030
# Epoch 21/1000 | Train Loss: 0.2746 | Train R²: 0.7278 | Val Loss: 0.2787 | Val R²: 0.7213 | Grad Norm: 2.9174e-01 | Duration: 0.0063
# Epoch 22/1000 | Train Loss: 0.2718 | Train R²: 0.7306 | Val Loss: 0.2760 | Val R²: 0.7240 | Grad Norm: 2.8075e-01 | Duration: 0.0036
# Epoch 23/1000 | Train Loss: 0.2684 | Train R²: 0.7339 | Val Loss: 0.2729 | Val R²: 0.7271 | Grad Norm: 2.6035e-01 | Duration: 0.0027
# Epoch 24/1000 | Train Loss: 0.2648 | Train R²: 0.7375 | Val Loss: 0.2696 | Val R²: 0.7304 | Grad Norm: 2.3216e-01 | Duration: 0.0035
# Epoch 25/1000 | Train Loss: 0.2612 | Train R²: 0.7411 | Val Loss: 0.2663 | Val R²: 0.7337 | Grad Norm: 1.9846e-01 | Duration: 0.0037
# Epoch 26/1000 | Train Loss: 0.2578 | Train R²: 0.7445 | Val Loss: 0.2634 | Val R²: 0.7366 | Grad Norm: 1.6329e-01 | Duration: 0.0077
# Epoch 27/1000 | Train Loss: 0.2548 | Train R²: 0.7474 | Val Loss: 0.2610 | Val R²: 0.7390 | Grad Norm: 1.3392e-01 | Duration: 0.0074
# Epoch 28/1000 | Train Loss: 0.2526 | Train R²: 0.7496 | Val Loss: 0.2592 | Val R²: 0.7408 | Grad Norm: 1.2138e-01 | Duration: 0.0057
# Epoch 29/1000 | Train Loss: 0.2512 | Train R²: 0.7510 | Val Loss: 0.2583 | Val R²: 0.7417 | Grad Norm: 1.3546e-01 | Duration: 0.0028
# Epoch 30/1000 | Train Loss: 0.2507 | Train R²: 0.7514 | Val Loss: 0.2581 | Val R²: 0.7419 | Grad Norm: 1.5081e-01 | Duration: 0.0033
# Epoch 31/1000 | Train Loss: 0.2503 | Train R²: 0.7519 | Val Loss: 0.2579 | Val R²: 0.7421 | Grad Norm: 1.5858e-01 | Duration: 0.0062
# Epoch 32/1000 | Train Loss: 0.2497 | Train R²: 0.7524 | Val Loss: 0.2575 | Val R²: 0.7425 | Grad Norm: 1.7188e-01 | Duration: 0.0042
# Epoch 33/1000 | Train Loss: 0.2490 | Train R²: 0.7532 | Val Loss: 0.2568 | Val R²: 0.7432 | Grad Norm: 1.8195e-01 | Duration: 0.0028
# Epoch 34/1000 | Train Loss: 0.2480 | Train R²: 0.7542 | Val Loss: 0.2559 | Val R²: 0.7442 | Grad Norm: 1.8678e-01 | Duration: 0.0030
# Epoch 35/1000 | Train Loss: 0.2468 | Train R²: 0.7554 | Val Loss: 0.2545 | Val R²: 0.7455 | Grad Norm: 1.8518e-01 | Duration: 0.0031
# Epoch 36/1000 | Train Loss: 0.2453 | Train R²: 0.7569 | Val Loss: 0.2527 | Val R²: 0.7473 | Grad Norm: 1.7656e-01 | Duration: 0.0040
# Epoch 37/1000 | Train Loss: 0.2436 | Train R²: 0.7585 | Val Loss: 0.2507 | Val R²: 0.7493 | Grad Norm: 1.6112e-01 | Duration: 0.0040
# Epoch 38/1000 | Train Loss: 0.2418 | Train R²: 0.7603 | Val Loss: 0.2485 | Val R²: 0.7515 | Grad Norm: 1.3966e-01 | Duration: 0.0030
# Epoch 39/1000 | Train Loss: 0.2401 | Train R²: 0.7620 | Val Loss: 0.2463 | Val R²: 0.7537 | Grad Norm: 1.1432e-01 | Duration: 0.0028
# Epoch 40/1000 | Train Loss: 0.2386 | Train R²: 0.7635 | Val Loss: 0.2442 | Val R²: 0.7558 | Grad Norm: 8.8766e-02 | Duration: 0.0033
# Epoch 41/1000 | Train Loss: 0.2374 | Train R²: 0.7647 | Val Loss: 0.2424 | Val R²: 0.7576 | Grad Norm: 7.1500e-02 | Duration: 0.0050
# Epoch 42/1000 | Train Loss: 0.2366 | Train R²: 0.7655 | Val Loss: 0.2410 | Val R²: 0.7590 | Grad Norm: 7.0803e-02 | Duration: 0.0029
# Epoch 43/1000 | Train Loss: 0.2360 | Train R²: 0.7661 | Val Loss: 0.2399 | Val R²: 0.7601 | Grad Norm: 8.2072e-02 | Duration: 0.0024
# Epoch 44/1000 | Train Loss: 0.2355 | Train R²: 0.7665 | Val Loss: 0.2393 | Val R²: 0.7607 | Grad Norm: 8.3649e-02 | Duration: 0.0022
# Epoch 45/1000 | Train Loss: 0.2350 | Train R²: 0.7670 | Val Loss: 0.2390 | Val R²: 0.7610 | Grad Norm: 7.2856e-02 | Duration: 0.0023
# Epoch 46/1000 | Train Loss: 0.2346 | Train R²: 0.7674 | Val Loss: 0.2387 | Val R²: 0.7613 | Grad Norm: 6.7941e-02 | Duration: 0.0028
# Epoch 47/1000 | Train Loss: 0.2343 | Train R²: 0.7677 | Val Loss: 0.2386 | Val R²: 0.7614 | Grad Norm: 7.0843e-02 | Duration: 0.0038
# Epoch 48/1000 | Train Loss: 0.2341 | Train R²: 0.7679 | Val Loss: 0.2386 | Val R²: 0.7614 | Grad Norm: 8.0165e-02 | Duration: 0.0023
# Epoch 49/1000 | Train Loss: 0.2340 | Train R²: 0.7680 | Val Loss: 0.2386 | Val R²: 0.7614 | Grad Norm: 9.2416e-02 | Duration: 0.0022
# Epoch 50/1000 | Train Loss: 0.2339 | Train R²: 0.7681 | Val Loss: 0.2386 | Val R²: 0.7614 | Grad Norm: 9.6476e-02 | Duration: 0.0035
# Epoch 51/1000 | Train Loss: 0.2337 | Train R²: 0.7683 | Val Loss: 0.2384 | Val R²: 0.7616 | Grad Norm: 8.9580e-02 | Duration: 0.0054
# Epoch 52/1000 | Train Loss: 0.2335 | Train R²: 0.7685 | Val Loss: 0.2382 | Val R²: 0.7618 | Grad Norm: 8.0352e-02 | Duration: 0.0051
# Epoch 53/1000 | Train Loss: 0.2332 | Train R²: 0.7688 | Val Loss: 0.2378 | Val R²: 0.7622 | Grad Norm: 7.0621e-02 | Duration: 0.0143
# Epoch 72/1000 | Train Loss: 0.2269 | Train R²: 0.7751 | Val Loss: 0.2315 | Val R²: 0.7685 | Grad Norm: 4.2971e-02 | Duration: 0.0021
# Epoch 73/1000 | Train Loss: 0.2266 | Train R²: 0.7754 | Val Loss: 0.2311 | Val R²: 0.7689 | Grad Norm: 4.1123e-02 | Duration: 0.0021
# Epoch 74/1000 | Train Loss: 0.2262 | Train R²: 0.7757 | Val Loss: 0.2308 | Val R²: 0.7692 | Grad Norm: 3.8602e-02 | Duration: 0.0023
# Epoch 75/1000 | Train Loss: 0.2259 | Train R²: 0.7761 | Val Loss: 0.2305 | Val R²: 0.7695 | Grad Norm: 3.5480e-02 | Duration: 0.0032
# Epoch 76/1000 | Train Loss: 0.2256 | Train R²: 0.7763 | Val Loss: 0.2302 | Val R²: 0.7699 | Grad Norm: 3.2256e-02 | Duration: 0.0028
# Epoch 77/1000 | Train Loss: 0.2253 | Train R²: 0.7766 | Val Loss: 0.2298 | Val R²: 0.7702 | Grad Norm: 2.9335e-02 | Duration: 0.0024
# Epoch 78/1000 | Train Loss: 0.2251 | Train R²: 0.7769 | Val Loss: 0.2296 | Val R²: 0.7704 | Grad Norm: 2.7762e-02 | Duration: 0.0021
# Epoch 79/1000 | Train Loss: 0.2249 | Train R²: 0.7771 | Val Loss: 0.2293 | Val R²: 0.7707 | Grad Norm: 2.7816e-02 | Duration: 0.0022
# Epoch 80/1000 | Train Loss: 0.2247 | Train R²: 0.7773 | Val Loss: 0.2291 | Val R²: 0.7709 | Grad Norm: 2.9052e-02 | Duration: 0.0022
# Epoch 81/1000 | Train Loss: 0.2245 | Train R²: 0.7775 | Val Loss: 0.2289 | Val R²: 0.7711 | Grad Norm: 3.1797e-02 | Duration: 0.0028
# Epoch 82/1000 | Train Loss: 0.2243 | Train R²: 0.7776 | Val Loss: 0.2287 | Val R²: 0.7713 | Grad Norm: 3.6696e-02 | Duration: 0.0026
# Epoch 83/1000 | Train Loss: 0.2241 | Train R²: 0.7778 | Val Loss: 0.2285 | Val R²: 0.7715 | Grad Norm: 3.9569e-02 | Duration: 0.0020
# Epoch 84/1000 | Train Loss: 0.2240 | Train R²: 0.7780 | Val Loss: 0.2283 | Val R²: 0.7717 | Grad Norm: 3.9380e-02 | Duration: 0.0021
# Epoch 85/1000 | Train Loss: 0.2238 | Train R²: 0.7782 | Val Loss: 0.2281 | Val R²: 0.7720 | Grad Norm: 3.8247e-02 | Duration: 0.0021
# Epoch 86/1000 | Train Loss: 0.2236 | Train R²: 0.7784 | Val Loss: 0.2278 | Val R²: 0.7722 | Grad Norm: 3.6345e-02 | Duration: 0.0021
# Epoch 87/1000 | Train Loss: 0.2234 | Train R²: 0.7786 | Val Loss: 0.2276 | Val R²: 0.7724 | Grad Norm: 3.4112e-02 | Duration: 0.0023
# Epoch 88/1000 | Train Loss: 0.2232 | Train R²: 0.7788 | Val Loss: 0.2273 | Val R²: 0.7727 | Grad Norm: 3.2102e-02 | Duration: 0.0024
# Epoch 140/1000 | Train Loss: 0.1708 | Train R²: 0.8306 | Val Loss: 0.1732 | Val R²: 0.8268 | Grad Norm: 8.4720e-02 | Duration: 0.0027
# Epoch 141/1000 | Train Loss: 0.1682 | Train R²: 0.8332 | Val Loss: 0.1705 | Val R²: 0.8295 | Grad Norm: 8.4325e-02 | Duration: 0.0024
# Epoch 142/1000 | Train Loss: 0.1656 | Train R²: 0.8359 | Val Loss: 0.1678 | Val R²: 0.8322 | Grad Norm: 8.3862e-02 | Duration: 0.0021
# Epoch 143/1000 | Train Loss: 0.1629 | Train R²: 0.8385 | Val Loss: 0.1650 | Val R²: 0.8350 | Grad Norm: 8.3043e-02 | Duration: 0.0024
# Epoch 144/1000 | Train Loss: 0.1602 | Train R²: 0.8412 | Val Loss: 0.1622 | Val R²: 0.8378 | Grad Norm: 8.2162e-02 | Duration: 0.0023
# Epoch 145/1000 | Train Loss: 0.1574 | Train R²: 0.8439 | Val Loss: 0.1594 | Val R²: 0.8406 | Grad Norm: 8.1129e-02 | Duration: 0.0027
# Epoch 146/1000 | Train Loss: 0.1547 | Train R²: 0.8467 | Val Loss: 0.1566 | Val R²: 0.8434 | Grad Norm: 8.0258e-02 | Duration: 0.0020
# Epoch 147/1000 | Train Loss: 0.1520 | Train R²: 0.8494 | Val Loss: 0.1538 | Val R²: 0.8462 | Grad Norm: 7.9555e-02 | Duration: 0.0020
# Epoch 148/1000 | Train Loss: 0.1492 | Train R²: 0.8521 | Val Loss: 0.1510 | Val R²: 0.8490 | Grad Norm: 7.9163e-02 | Duration: 0.0024
# Epoch 149/1000 | Train Loss: 0.1465 | Train R²: 0.8547 | Val Loss: 0.1483 | Val R²: 0.8517 | Grad Norm: 7.9238e-02 | Duration: 0.0026
# Epoch 150/1000 | Train Loss: 0.1439 | Train R²: 0.8574 | Val Loss: 0.1455 | Val R²: 0.8545 | Grad Norm: 7.9787e-02 | Duration: 0.0031
# Epoch 151/1000 | Train Loss: 0.1412 | Train R²: 0.8600 | Val Loss: 0.1428 | Val R²: 0.8572 | Grad Norm: 8.0768e-02 | Duration: 0.0029
# Epoch 152/1000 | Train Loss: 0.1386 | Train R²: 0.8626 | Val Loss: 0.1400 | Val R²: 0.8600 | Grad Norm: 8.2146e-02 | Duration: 0.0031
# Epoch 153/1000 | Train Loss: 0.1360 | Train R²: 0.8652 | Val Loss: 0.1374 | Val R²: 0.8626 | Grad Norm: 8.3644e-02 | Duration: 0.0023
# Epoch 154/1000 | Train Loss: 0.1333 | Train R²: 0.8678 | Val Loss: 0.1347 | Val R²: 0.8653 | Grad Norm: 8.5722e-02 | Duration: 0.0021
# Epoch 155/1000 | Train Loss: 0.1307 | Train R²: 0.8704 | Val Loss: 0.1320 | Val R²: 0.8680 | Grad Norm: 8.7836e-02 | Duration: 0.0021
# Epoch 156/1000 | Train Loss: 0.1281 | Train R²: 0.8730 | Val Loss: 0.1294 | Val R²: 0.8706 | Grad Norm: 8.9843e-02 | Duration: 0.0028
# Epoch 157/1000 | Train Loss: 0.1255 | Train R²: 0.8756 | Val Loss: 0.1267 | Val R²: 0.8733 | Grad Norm: 9.2078e-02 | Duration: 0.0034
# Epoch 158/1000 | Train Loss: 0.1229 | Train R²: 0.8782 | Val Loss: 0.1238 | Val R²: 0.8762 | Grad Norm: 9.8284e-02 | Duration: 0.0029
# Epoch 159/1000 | Train Loss: 0.1204 | Train R²: 0.8806 | Val Loss: 0.1211 | Val R²: 0.8789 | Grad Norm: 1.1293e-01 | Duration: 0.0028
# Epoch 160/1000 | Train Loss: 0.1180 | Train R²: 0.8831 | Val Loss: 0.1184 | Val R²: 0.8816 | Grad Norm: 1.2613e-01 | Duration: 0.0026
# Epoch 161/1000 | Train Loss: 0.1155 | Train R²: 0.8855 | Val Loss: 0.1158 | Val R²: 0.8842 | Grad Norm: 1.3326e-01 | Duration: 0.0030
# Epoch 162/1000 | Train Loss: 0.1130 | Train R²: 0.8880 | Val Loss: 0.1132 | Val R²: 0.8868 | Grad Norm: 1.3702e-01 | Duration: 0.0036
# Epoch 163/1000 | Train Loss: 0.1105 | Train R²: 0.8904 | Val Loss: 0.1107 | Val R²: 0.8893 | Grad Norm: 1.3707e-01 | Duration: 0.0034
# Epoch 164/1000 | Train Loss: 0.1080 | Train R²: 0.8929 | Val Loss: 0.1081 | Val R²: 0.8919 | Grad Norm: 1.3384e-01 | Duration: 0.0034
# Epoch 165/1000 | Train Loss: 0.1055 | Train R²: 0.8954 | Val Loss: 0.1056 | Val R²: 0.8944 | Grad Norm: 1.2866e-01 | Duration: 0.0027
# Epoch 166/1000 | Train Loss: 0.1030 | Train R²: 0.8979 | Val Loss: 0.1032 | Val R²: 0.8968 | Grad Norm: 1.2341e-01 | Duration: 0.0031
# Epoch 167/1000 | Train Loss: 0.1006 | Train R²: 0.9003 | Val Loss: 0.1009 | Val R²: 0.8991 | Grad Norm: 1.1985e-01 | Duration: 0.0044
# Epoch 168/1000 | Train Loss: 0.0983 | Train R²: 0.9026 | Val Loss: 0.0987 | Val R²: 0.9013 | Grad Norm: 1.1872e-01 | Duration: 0.0034
# Epoch 169/1000 | Train Loss: 0.0960 | Train R²: 0.9048 | Val Loss: 0.0966 | Val R²: 0.9034 | Grad Norm: 1.1900e-01 | Duration: 0.0029
# Epoch 170/1000 | Train Loss: 0.0939 | Train R²: 0.9069 | Val Loss: 0.0946 | Val R²: 0.9054 | Grad Norm: 1.1854e-01 | Duration: 0.0026
# Epoch 171/1000 | Train Loss: 0.0919 | Train R²: 0.9089 | Val Loss: 0.0927 | Val R²: 0.9073 | Grad Norm: 1.1500e-01 | Duration: 0.0027
# Epoch 172/1000 | Train Loss: 0.0901 | Train R²: 0.9107 | Val Loss: 0.0910 | Val R²: 0.9090 | Grad Norm: 1.0685e-01 | Duration: 0.0031
# Epoch 173/1000 | Train Loss: 0.0884 | Train R²: 0.9124 | Val Loss: 0.0895 | Val R²: 0.9105 | Grad Norm: 9.4754e-02 | Duration: 0.0027
# Epoch 174/1000 | Train Loss: 0.0869 | Train R²: 0.9138 | Val Loss: 0.0883 | Val R²: 0.9117 | Grad Norm: 8.2236e-02 | Duration: 0.0027
# Epoch 347/1000 | Train Loss: 0.0397 | Train R²: 0.9607 | Val Loss: 0.0401 | Val R²: 0.9599 | Grad Norm: 3.8140e-02 | Duration: 0.0024
# Epoch 348/1000 | Train Loss: 0.0394 | Train R²: 0.9609 | Val Loss: 0.0399 | Val R²: 0.9601 | Grad Norm: 5.0254e-02 | Duration: 0.0042
# Epoch 349/1000 | Train Loss: 0.0392 | Train R²: 0.9612 | Val Loss: 0.0396 | Val R²: 0.9604 | Grad Norm: 5.8879e-02 | Duration: 0.0036
# Epoch 350/1000 | Train Loss: 0.0389 | Train R²: 0.9614 | Val Loss: 0.0394 | Val R²: 0.9606 | Grad Norm: 6.0768e-02 | Duration: 0.0029
# Epoch 351/1000 | Train Loss: 0.0386 | Train R²: 0.9617 | Val Loss: 0.0391 | Val R²: 0.9609 | Grad Norm: 5.5848e-02 | Duration: 0.0027
# Epoch 352/1000 | Train Loss: 0.0383 | Train R²: 0.9620 | Val Loss: 0.0388 | Val R²: 0.9612 | Grad Norm: 4.7274e-02 | Duration: 0.0032
# Epoch 353/1000 | Train Loss: 0.0380 | Train R²: 0.9624 | Val Loss: 0.0385 | Val R²: 0.9615 | Grad Norm: 4.1786e-02 | Duration: 0.0045
# Epoch 354/1000 | Train Loss: 0.0377 | Train R²: 0.9627 | Val Loss: 0.0382 | Val R²: 0.9618 | Grad Norm: 4.5233e-02 | Duration: 0.0032
# Epoch 355/1000 | Train Loss: 0.0374 | Train R²: 0.9630 | Val Loss: 0.0379 | Val R²: 0.9621 | Grad Norm: 5.4271e-02 | Duration: 0.0024
# Epoch 356/1000 | Train Loss: 0.0370 | Train R²: 0.9633 | Val Loss: 0.0375 | Val R²: 0.9625 | Grad Norm: 5.3137e-02 | Duration: 0.0020
# Epoch 357/1000 | Train Loss: 0.0367 | Train R²: 0.9636 | Val Loss: 0.0372 | Val R²: 0.9628 | Grad Norm: 4.7773e-02 | Duration: 0.0022
# Epoch 358/1000 | Train Loss: 0.0363 | Train R²: 0.9640 | Val Loss: 0.0368 | Val R²: 0.9632 | Grad Norm: 4.1135e-02 | Duration: 0.0025
# ...
# Epoch 882/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 1.1706e-03 | Duration: 0.0020
# Epoch 883/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 1.1375e-03 | Duration: 0.0022
# Epoch 884/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 1.4483e-03 | Duration: 0.0021
# Epoch 885/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 1.5736e-03 | Duration: 0.0020
# Epoch 886/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 1.3293e-03 | Duration: 0.0021
# Epoch 887/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 8.5551e-04 | Duration: 0.0028
# Epoch 888/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 1.0740e-03 | Duration: 0.0028
# Epoch 889/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 1.3753e-03 | Duration: 0.0029
# Epoch 890/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 1.3846e-03 | Duration: 0.0026
# Epoch 891/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 1.0647e-03 | Duration: 0.0024
# Epoch 892/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 8.2153e-04 | Duration: 0.0025
# Epoch 893/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 1.4727e-03 | Duration: 0.0028
# Epoch 894/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 1.8880e-03 | Duration: 0.0036
# Epoch 895/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 1.6561e-03 | Duration: 0.0032
# Epoch 896/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 1.0293e-03 | Duration: 0.0026
# Epoch 897/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 1.0445e-03 | Duration: 0.0023
# Epoch 898/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 1.6700e-03 | Duration: 0.0029
# Epoch 899/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 1.8883e-03 | Duration: 0.0033
# Epoch 900/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 1.5414e-03 | Duration: 0.0026
# Epoch 901/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 8.8167e-04 | Duration: 0.0022
# Epoch 902/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 1.1776e-03 | Duration: 0.0020
# Epoch 903/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 1.7920e-03 | Duration: 0.0020
# Epoch 904/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 1.0925e-03 | Duration: 0.0026
# Epoch 905/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 3.0151e-03 | Duration: 0.0026
# Epoch 906/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 1.9015e-03 | Duration: 0.0023
# Epoch 907/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 2.4629e-03 | Duration: 0.0021
# Epoch 908/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 4.0620e-03 | Duration: 0.0021
# Epoch 909/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 3.3234e-03 | Duration: 0.0020
# Epoch 910/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 1.6322e-03 | Duration: 0.0022
# Epoch 911/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 1.2915e-03 | Duration: 0.0023
# Epoch 912/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 2.3956e-03 | Duration: 0.0027
# Epoch 913/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 2.4539e-03 | Duration: 0.0024
# Epoch 914/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 1.5339e-03 | Duration: 0.0021
# Epoch 915/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 1.0583e-03 | Duration: 0.0023
# Epoch 916/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 1.8181e-03 | Duration: 0.0022
# Epoch 917/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 1.9181e-03 | Duration: 0.0022
# Epoch 918/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 1.1832e-03 | Duration: 0.0027
# Epoch 919/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 7.0807e-04 | Duration: 0.0026
# Epoch 920/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 1.3886e-03 | Duration: 0.0021
# Epoch 921/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 1.6126e-03 | Duration: 0.0021
# Epoch 922/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 1.2547e-03 | Duration: 0.0020
# Epoch 923/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 6.3576e-04 | Duration: 0.0021
# Epoch 924/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 9.2910e-04 | Duration: 0.0023
# Epoch 925/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 1.0944e-03 | Duration: 0.0029
# Epoch 926/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 7.2543e-04 | Duration: 0.0023
# Epoch 927/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 6.2879e-04 | Duration: 0.0029
# Epoch 928/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 1.0257e-03 | Duration: 0.0026
# Epoch 929/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 1.2485e-03 | Duration: 0.0024
# Epoch 930/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 1.0929e-03 | Duration: 0.0024
# Epoch 931/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 7.1594e-04 | Duration: 0.0028
# Epoch 932/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 7.1873e-04 | Duration: 0.0040
# Epoch 933/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 6.8040e-04 | Duration: 0.0023
# Epoch 934/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 5.9919e-04 | Duration: 0.0032
# Epoch 935/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 5.9207e-04 | Duration: 0.0039
# Epoch 936/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 6.6520e-04 | Duration: 0.0039
# Epoch 937/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 7.0375e-04 | Duration: 0.0053
# Epoch 938/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 6.6338e-04 | Duration: 0.0032
# Epoch 939/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 6.1151e-04 | Duration: 0.0038
# Epoch 940/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 6.0814e-04 | Duration: 0.0043
# Epoch 941/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 6.7246e-04 | Duration: 0.0031
# Epoch 942/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 5.6922e-04 | Duration: 0.0023
# Epoch 943/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 5.7762e-04 | Duration: 0.0020
# Epoch 944/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 6.9648e-04 | Duration: 0.0023
# Epoch 945/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 7.6289e-04 | Duration: 0.0026
# Epoch 946/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 7.1834e-04 | Duration: 0.0024
# Epoch 947/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 6.4085e-04 | Duration: 0.0021
# Epoch 948/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 6.4862e-04 | Duration: 0.0033
# Epoch 949/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 7.0862e-04 | Duration: 0.0022
# Epoch 950/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 7.1292e-04 | Duration: 0.0021
# Epoch 951/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 6.5291e-04 | Duration: 0.0025
# Epoch 952/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 6.3760e-04 | Duration: 0.0028
# Epoch 953/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 5.9549e-04 | Duration: 0.0027
# Epoch 954/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 5.7868e-04 | Duration: 0.0023
# Epoch 955/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 5.7558e-04 | Duration: 0.0022
# Epoch 956/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 6.0236e-04 | Duration: 0.0020
# Epoch 957/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 6.3481e-04 | Duration: 0.0022
# Epoch 958/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 6.4895e-04 | Duration: 0.0032
# Epoch 959/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 6.2925e-04 | Duration: 0.0024
# Epoch 960/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 5.5233e-04 | Duration: 0.0020
# Epoch 961/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 5.1125e-04 | Duration: 0.0027
# Epoch 962/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 5.0643e-04 | Duration: 0.0032
# Epoch 963/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 5.7202e-04 | Duration: 0.0026
# Epoch 964/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 5.4209e-04 | Duration: 0.0026
# Epoch 965/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 5.7647e-04 | Duration: 0.0034
# Epoch 966/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 5.2666e-04 | Duration: 0.0028
# Epoch 967/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 8.9493e-04 | Duration: 0.0029
# Epoch 968/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 1.1521e-03 | Duration: 0.0023
# Epoch 969/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 8.9177e-04 | Duration: 0.0022
# Epoch 970/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 6.9156e-04 | Duration: 0.0033
# Epoch 971/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 6.7889e-04 | Duration: 0.0027
# Epoch 972/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 8.3597e-04 | Duration: 0.0022
# Epoch 973/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 6.1889e-04 | Duration: 0.0022
# Epoch 974/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 1.3223e-03 | Duration: 0.0021
# Epoch 975/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 6.6472e-04 | Duration: 0.0022
# Epoch 976/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 5.7978e-04 | Duration: 0.0031
# Epoch 977/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 7.4751e-04 | Duration: 0.0022
# Epoch 978/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 4.3266e-04 | Duration: 0.0021
# Epoch 979/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 1.0225e-03 | Duration: 0.0022
# Epoch 980/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 1.3540e-03 | Duration: 0.0023
# Epoch 981/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 7.5380e-04 | Duration: 0.0020
# Epoch 982/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 5.1280e-04 | Duration: 0.0026
# Epoch 983/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 8.9472e-04 | Duration: 0.0026
# Epoch 984/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 6.5210e-04 | Duration: 0.0026
# Epoch 985/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 4.5862e-04 | Duration: 0.0021
# Epoch 986/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 9.8568e-04 | Duration: 0.0021
# Epoch 987/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 1.0031e-03 | Duration: 0.0020
# Epoch 988/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 4.8672e-04 | Duration: 0.0025
# Epoch 989/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 6.2289e-04 | Duration: 0.0023
# Epoch 990/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 8.9752e-04 | Duration: 0.0027
# Epoch 991/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 8.3446e-04 | Duration: 0.0022
# Epoch 992/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 5.5302e-04 | Duration: 0.0022
# Epoch 993/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 4.6005e-04 | Duration: 0.0023
# Epoch 994/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 7.1226e-04 | Duration: 0.0020
# Epoch 995/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 8.9772e-04 | Duration: 0.0023
# Epoch 996/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 8.2639e-04 | Duration: 0.0030
# Epoch 997/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 6.1321e-04 | Duration: 0.0022
# Epoch 998/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 4.0965e-04 | Duration: 0.0021
# Epoch 999/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 6.3587e-04 | Duration: 0.0021
# Epoch 1000/1000 | Train Loss: 0.0104 | Train R²: 0.9897 | Val Loss: 0.0104 | Val R²: 0.9896 | Grad Norm: 7.9117e-04 | Duration: 0.0021

# %%
def optimize_hyper_params_lfrog(folds, time_list, delta_list, j_list, max_epochs=1000):
    results = {}
    for t in time_list:
        for d in delta_list:
            for j in j_list:
                results_per_config = {}
                for i in tqdm(range(len(folds))):
                    results_per_config[f'fold_{i}'] = train_leapfrog_model(folds[i], max_epochs=max_epochs, time_step=t, delta_max=d, j_threshold=j, to_print=False, patience=1000)
                results[f'timestep_{t}_delta_{d}_J_{j}'] = results_per_config
    return results

# %%
time_list = [0.1, 0.25, 0.5, 0.75, 1.0]
delta_list = [0.5, 1.0, 1.5, 2.0]
j_list = [1, 2, 3, 4]

lfrog_param_results = optimize_hyper_params_lfrog(folds, time_list, delta_list, j_list)
save_json(extract_losses_and_accuracy(lfrog_param_results), '../results/regression_1/lfrog_hyperparam_test.json')
# Out:
# 100%|██████████| 10/10 [00:39<00:00,  3.95s/it]
# 100%|██████████| 10/10 [00:34<00:00,  3.46s/it]
# 100%|██████████| 10/10 [00:32<00:00,  3.29s/it]
# 100%|██████████| 10/10 [00:37<00:00,  3.74s/it]
# 100%|██████████| 10/10 [00:36<00:00,  3.68s/it]
# 100%|██████████| 10/10 [00:33<00:00,  3.38s/it]
# 100%|██████████| 10/10 [00:36<00:00,  3.62s/it]
# 100%|██████████| 10/10 [00:31<00:00,  3.19s/it]
# 100%|██████████| 10/10 [00:31<00:00,  3.17s/it]
# 100%|██████████| 10/10 [00:32<00:00,  3.23s/it]
# 100%|██████████| 10/10 [00:30<00:00,  3.01s/it]
# 100%|██████████| 10/10 [00:30<00:00,  3.03s/it]
# 100%|██████████| 10/10 [00:31<00:00,  3.18s/it]
# 100%|██████████| 10/10 [00:35<00:00,  3.55s/it]
# 100%|██████████| 10/10 [00:36<00:00,  3.66s/it]
# 100%|██████████| 10/10 [00:37<00:00,  3.78s/it]
# 100%|██████████| 10/10 [00:33<00:00,  3.38s/it]
# 100%|██████████| 10/10 [00:29<00:00,  2.99s/it]
# 100%|██████████| 10/10 [00:24<00:00,  2.48s/it]
# 100%|██████████| 10/10 [00:20<00:00,  2.08s/it]
# 100%|██████████| 10/10 [00:31<00:00,  3.19s/it]
# 100%|██████████| 10/10 [00:36<00:00,  3.65s/it]
# 100%|██████████| 10/10 [00:23<00:00,  2.37s/it]
# 100%|██████████| 10/10 [00:28<00:00,  2.84s/it]
# 100%|██████████| 10/10 [00:37<00:00,  3.77s/it]
# 100%|██████████| 10/10 [00:37<00:00,  3.72s/it]
# 100%|██████████| 10/10 [00:32<00:00,  3.24s/it]
# 100%|██████████| 10/10 [00:26<00:00,  2.62s/it]
# 100%|██████████| 10/10 [00:35<00:00,  3.55s/it]
# 100%|██████████| 10/10 [00:33<00:00,  3.34s/it]
# 100%|██████████| 10/10 [00:24<00:00,  2.49s/it]
# 100%|██████████| 10/10 [00:37<00:00,  3.75s/it]
# 100%|██████████| 10/10 [00:27<00:00,  2.77s/it]
# 100%|██████████| 10/10 [00:33<00:00,  3.39s/it]
# 100%|██████████| 10/10 [00:25<00:00,  2.54s/it]
# 100%|██████████| 10/10 [00:20<00:00,  2.02s/it]
#  'timestep_1.0_delta_2.0_J_1',
#  'timestep_0.5_delta_2.0_J_3',
#  'timestep_0.5_delta_1.0_J_1',
#  'timestep_0.5_delta_0.5_J_2',
#  'timestep_0.5_delta_2.0_J_1',
#  'timestep_0.25_delta_1.5_J_3',
#  'timestep_0.25_delta_1.0_J_2',
#  'timestep_0.25_delta_1.5_J_2',
#  'timestep_0.25_delta_2.0_J_4',
#  'timestep_0.25_delta_1.5_J_1',
#  'timestep_0.75_delta_0.5_J_1',
#  'timestep_0.5_delta_0.5_J_1',
#  'timestep_0.1_delta_0.5_J_4',
#  'timestep_0.1_delta_2.0_J_4',
#  'timestep_0.75_delta_2.0_J_1',
#  'timestep_0.75_delta_1.0_J_4',
#  'timestep_0.75_delta_0.5_J_4',
#  'timestep_1.0_delta_1.0_J_2',
#  'timestep_0.75_delta_1.5_J_1',
#  'timestep_0.75_delta_1.0_J_3',
#  'timestep_1.0_delta_0.5_J_1',
#  'timestep_1.0_delta_0.5_J_2',
#  'timestep_0.5_delta_1.5_J_3',
#  'timestep_1.0_delta_2.0_J_3',
#  'timestep_0.5_delta_0.5_J_3',
#  'timestep_0.75_delta_2.0_J_2',
#  'timestep_1.0_delta_1.0_J_1',
#  'timestep_0.5_delta_1.5_J_1',
#  'timestep_0.25_delta_1.5_J_4',
#  'timestep_0.25_delta_1.0_J_1',
#  'timestep_0.25_delta_2.0_J_1',
#  'timestep_0.25_delta_0.5_J_1',
#  'timestep_0.1_delta_1.5_J_2',
#  'timestep_0.1_delta_2.0_J_1',
#  'timestep_0.1_delta_1.5_J_4',
#  'timestep_0.1_delta_1.0_J_3',
#  'timestep_0.1_delta_0.5_J_2',
#  'timestep_0.1_delta_2.0_J_3',
#  'timestep_0.1_delta_2.0_J_2',
#  'timestep_0.1_delta_1.0_J_4',
#  'timestep_0.1_delta_0.5_J_1',
#  'timestep_0.75_delta_1.0_J_2',
#  'timestep_0.75_delta_1.5_J_2',
#  'timestep_1.0_delta_1.5_J_4',
#  'timestep_0.75_delta_1.5_J_3',
#  'timestep_1.0_delta_0.5_J_3',
#  'timestep_0.75_delta_2.0_J_3',
#  'timestep_0.5_delta_1.5_J_4',
#  'timestep_1.0_delta_1.0_J_4',
#  'timestep_0.75_delta_2.0_J_4',
#  'timestep_0.5_delta_1.0_J_2',
#  'timestep_1.0_delta_1.5_J_1',
#  'timestep_0.5_delta_1.0_J_4',
#  'timestep_0.5_delta_2.0_J_2',
#  'timestep_0.25_delta_1.0_J_3',
#  'timestep_0.25_delta_2.0_J_2',
#  'timestep_0.25_delta_0.5_J_3',
#  'timestep_0.25_delta_1.0_J_4',
#  'timestep_0.1_delta_1.5_J_3',
#  'timestep_0.1_delta_1.0_J_2',
#  'timestep_0.1_delta_1.5_J_1',
#  'timestep_0.1_delta_1.0_J_1',
#  'timestep_0.75_delta_0.5_J_2',
#  'timestep_1.0_delta_1.0_J_3',
#  'timestep_0.75_delta_1.5_J_4',
#  'timestep_0.5_delta_1.0_J_3',
#  'timestep_0.5_delta_0.5_J_4',
#  'timestep_0.5_delta_1.5_J_2',
#  'timestep_1.0_delta_1.5_J_2',
#  'timestep_0.5_delta_2.0_J_4',
#  'timestep_0.25_delta_0.5_J_2',
#  'timestep_0.25_delta_0.5_J_4',
#  'timestep_0.75_delta_0.5_J_3',
#  'timestep_0.1_delta_0.5_J_3',
#  'timestep_1.0_delta_0.5_J_4',
#  'timestep_0.25_delta_2.0_J_3']

# %%
plot_per_dim(lfrog_param_results['timestep_1.0_delta_2.0_J_2'])

# %%
estimate_avg_time_to_convergence(lfrog_param_results['timestep_1.0_delta_2.0_J_2'])
# Out:
# {'val_wall_avg': 0.10776848793029785,
#  'val_wall_std': 0.020444467076148484,
#  'val_epoch_avg': 22.1,
#  'val_epoch_std': 4.109744517606903,
#  'train_wall_avg': 0.1035015344619751,
#  'train_wall_std': 0.016644018701974395,
#  'train_epoch_avg': 21.2,
#  'train_epoch_std': 3.867815921162743}

# %% [markdown]
# ## Evals

# %%
def stat_tests(sgd, scg, lfrog, metric, signifigance_level = 0.05, conv_threshold = 0.05):

    best_sgd_key = sort_configs(sgd, threshold=conv_threshold, test_key=metric)[0]
    best_scg_key = sort_configs(scg, threshold=conv_threshold, test_key=metric)[0]
    best_lfrog_key = sort_configs(lfrog, threshold=conv_threshold, test_key=metric)[0]

    sgd_data = find_time_to_convergence(dim_results_lr[best_sgd_key], threshold=conv_threshold)[metric]
    scg_data = find_time_to_convergence(scg_param_results[best_scg_key], threshold=conv_threshold)[metric]
    lfrog_data = find_time_to_convergence(lfrog_param_results[best_lfrog_key], threshold=conv_threshold)[metric]

    column_names = [f'fold {i}' for i in range(10)]
    df = pd.DataFrame([sgd_data, scg_data, lfrog_data], columns=column_names) 
    df = df.T
    df.columns = ['SGD', 'SCG', 'LFROG']

    map = {
        'val_wall': 'Validation Wall Time (Time to Convergence)',
        'val_epoch': 'Validation Epochs (Epochs to Convergence)', 
        'train_wall': 'Training Wall Time (Time to Convergence)',
        'train_epoch': 'Training Epochs (Epochs to Convergence)'
        }

    posthoc_results = sp.posthoc_nemenyi_friedman(df)
    plt.title(f'Signifigance Plot between best KNN and DT models based on {map[metric]}')
    sp.sign_plot(posthoc_results)
    plt.title('p-value')
    plt.show

    f = io.StringIO()
    with redirect_stdout(f):
        results = autorank(df, alpha=signifigance_level, verbose=False, force_mode='nonparametric', order='ascending')
    plot_stats(results)
    plt.title(f'Critical Distance plot based on {map[metric]}')
    plt.show()

    ranking_order = results.rankdf.index.tolist()
    for k in ranking_order:
        if k == 'SGD':
            out = estimate_avg_time_to_convergence(sgd[best_sgd_key], threshold=conv_threshold)
        if k == 'SCG':
            out = estimate_avg_time_to_convergence(scg[best_scg_key], threshold=conv_threshold)
        if k == 'LFROG':
            out = estimate_avg_time_to_convergence(lfrog[best_lfrog_key], threshold=conv_threshold)
        print(f"{k}: {out[metric+'_avg']} ± {out[metric+'_std']}")

# %%
stat_tests(dim_results_lr, scg_param_results, lfrog_param_results, metric='val_epoch', signifigance_level=0.05)
